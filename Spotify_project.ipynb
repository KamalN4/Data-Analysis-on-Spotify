# %% [markdown]
# ![11167spotify-logo-1920x1080-2-thumbnail_webp-600x300.png](attachment:11167spotify-logo-1920x1080-2-thumbnail_webp-600x300.png)

# %% [markdown]
# <div style="text-align: center"> <h1>Data Analysis on Spotify Dataset</h1></div>
#
# The Spotify dataset provides insight into users data about which songs they listen to, and not just the popularity of tracks, but also features of the tracks they have in their library as recorded in their database.Moreover this will help to make a better targeted content distribution that would be helpful for the developers and the marketing team to analyze trends and help them to segments users better and try to increase profits and provide a better user experience.
# The libraries for Data analysis and Visualisation that I have used in this Project are Numpy,Pandas,Matplotlib and Seaborn.
# In this project I'm trying to understand and analyze relationship between popularity and different features of the song.
# This is mainly useful to market songs to the spotify users and improve their experience while using it.

# %% [markdown]
# # Loading important tools

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
tracks = pd .read_csv('tracks.csv')

# %%
tracks.head(10)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
# 5  0BRXJHRNGQ3W4v9frnSfhu                            Ave Maria           0
# 6  0Dd9ImXtAtGwsmsAD69KZT                       La Butte Rouge           0
# 7  0IA0Hju8CAgYfV1hwhidBH                              La Java           0
# 8  0IgI1UCz84pYeVetnl1lGP                   Old Fashioned Girl           0
# 9  0JV4iqw2lSKJaHBQZ0e5zK        Martín Fierro - Remasterizado           0
#
#    duration_ms  explicit              artists                  id_artists  \
# ...

# %% [markdown]
# This dataset contains 586672 rows and 20 columns

# %% [markdown]
# # Preliminary Analysis and Cleaning

# %% [markdown]
# ## Checking out for null values

# %%
pd.isnull(tracks).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %% [markdown]
# ## Dropping out null values

# %%
tracks = tracks.dropna(axis =0)
pd.isnull(tracks).sum()
# Out:
# id                  0
# name                0
# popularity          0
# duration_ms         0
# explicit            0
# artists             0
# id_artists          0
# release_date        0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %% [markdown]
# ## Checking out for duplicated values

# %%
tracks.duplicated().sum()
# Out:
# 0

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %% [markdown]
# ## Explanation of column names that are used for analysis
# **id** - It is the id of that song (also the primary key)<br>
# **name** - The name of that song <br>
# **popularity** - On a scale of 0 - 100 songs have been classified as per their popularity<br>
# **duration_ms** - This column refers to duration of songs in milliseconds which will be further converted in seconds<br>
# **artists** - Name of the artist that have worked on that song <br>
# **id_artists** - Identifier for artists <br>
# **release_date** - Date corresponding to which the song was released<br>
# **danceability** - On a scale of 0-1 it measures the value returned corresponding to the ease with which a person could dance to a song over the course of the whole song.<br>
# **energy** - The music is probably loud, rhythmically active, and is the kind of music that gets the blood pumping.<br>
# **key** - Key in music is a system of functionally related chords deriving from the major and minor scales, with a central note, called the tonic (or keynote).<br>
# **Loudness** -  It refers to how loud or soft a sound seems to a distant listener<br>
# **mode** - Music is classified into two modes major and minor which are further sub-divided into 7 .<br>
# **Speechiness** -  Speechiness detects the presence of spoken words in a track. e.g. talk show, audio book, poetry<br>
# **valence** - Describes the musical positiveness conveyed by a track<br>
# **tempo**- Tempo is the Italian word for the speed of a song or piece of music.<br>
# **time_signature** - Time signatures, or meter signatures, indicate how many beats are in each measure of a piece of music, as well as which note value is counted as a beat.<br>

# %% [markdown]
# ##  Fetching 10 least popular songs

# %%
sorted_tracks = tracks.sort_values('popularity' , ascending = True)

# %%
sorted_tracks.head(10)
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %% [markdown]
# ## Obtaining 10 most popular songs which have popularity value >80

# %%
most_popular = tracks[tracks['popularity'] > 80].sort_values('popularity' , ascending = False)
most_popular.head(10)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92817  27OeeYzk6klgBh83TSvGMA                             WITHOUT YOU
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %% [markdown]
# ## Popularity count of songs

# %%
df =tracks['popularity'].value_counts()
df.sort_values
# Out:
# <bound method Series.sort_values of 0      44690
# 35     12231
# 23     12139
# 1      12024
# 36     11879
#        ...
# 93         2
# 95         1
# 100        1
# 99         1
# 98         1
# Name: popularity, Length: 101, dtype: int64>

# %% [markdown]
# ## Types of Key that the song has

# %%
tracks['key'].value_counts()
# Out:
# 0     74940
# 7     73772
# 2     66550
# 9     65124
# 5     53605
# 4     48214
# 1     41731
# 11    39128
# 10    37700
# 8     33457
# 6     30852
# 3     21528
# Name: key, dtype: int64

# %% [markdown]
# ## Grouping songs date-wise

# %%
tracks['release_date'] = pd.to_datetime(tracks['release_date'] , format='%Y-%m-%d ')

# %%
tracks['release_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
tracks['year'] = tracks['release_date'].dt.year

# %%
tracks.set_index('release_date' , inplace = True)

# %%
tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922-01-01             0       163080         0      ['Dick Haymes']
#
# ...

# %% [markdown]
# ## Understanding attributes of top 10 songs having max duration

# %%
tracks.sort_values(['duration_ms']).head(10)
# Out:
#                           id         name  popularity  duration_ms  explicit  \
# 1575  4WeyR22Ax2fF9dY0NxgjFV  Pause Track           0         3344         0
# 1441  2s6e7KLoQ5hie3Cnh73v2v  Pause Track           0         3344         0
# 1620  52qf3kN9pExTlHdSlh3ZeR  Pause Track           0         3344         0
# 1570  4SjlyAejCNUB4MrGM1KuVp  Pause Track           0         3344         0
# 1843  7nZNkbxnRyx1DqPC6ro6Je  Pause Track           0         4000         0
# 1429  2jdIDTMKpzrw7agn1Whtse  Pause Track           0         4000         0
# 1423  2fKnluaRpiiCFHWwKFkIgN  Pause Track           0         4000         0
# 1824  7bgYtpP5qxWabDHsPY8Rwc  Pause Track           0         4000         0
# 1753  6XWCeD5XNqZr5XPVZUDn1G  Pause Track           0         4000         0
# 1291  1JUFU8XJRWgG9Ir8KlLvpW  Pause Track           0         4000         0
#
#                   artists                  id_artists release_date  \
# ...

# %% [markdown]
# ## Converting duration from milli-seconds to seconds

# %%
tracks['duration'] = tracks['duration_ms'].apply(lambda x:round(x/1000) )
tracks.drop('duration_ms', axis = 1 , inplace = True)

# %%
tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  explicit              artists  \
# release_date
# 1922-02-22             6         0              ['Uli']
# 1922-06-01             0         0  ['Fernando Pessoa']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-01-01             0         0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# ...

# %% [markdown]
# # Visualization and Analysis

# %% [markdown]
# ## Taking a representative sample out of dataset for analysis

# %%
sample_track = tracks.sample(int(0.004*len(tracks)))

# %%
print(len(sample_track))
# Out:
# 2346

# %% [markdown]
# ## Relation between Population and energy on representative data

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = sample_track , y = 'popularity' , x = 'energy' , color = 'b').set(title = 'Popularity versus energy')
# Out:
# [Text(0.5, 1.0, 'Popularity versus energy')]

# %% [markdown]
# ## Relation Between popularity and loudness

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = sample_track , y = 'popularity' , x = 'loudness' , color = 'c').set(title = 'Popularity versus loudness')
# Out:
# [Text(0.5, 1.0, 'Popularity versus loudness')]

# %% [markdown]
# ## Relation between loudness and energy

# %%
plt.figure(figsize=(10,8))
sns.regplot(data = sample_track , y = 'loudness' , x='loudness' , color = 'm' ).set(title = 'Loudness versus Energy')
# Out:
# [Text(0.5, 1.0, 'Loudness versus Energy')]

# %% [markdown]
# ## Count of songs year wise

# %%
plt.figure(figsize=(12,10))
sns.set(style = 'darkgrid')
sns.displot(data = tracks , x = 'year' ,kind = 'hist' , bins = 100)

# %% [markdown]
# # Importing SpotifyFeatures.csv file for analysis

# %%
genre = pd.read_csv('SpotifyFeatures.csv')

# %%
genre.head()

# %% [markdown]
# ## Total no. of singers on Spotify

# %%
all_singers = []
for i in genre['artist_name']:
    all_singers += i.split('&')
print('Total number of unique singers are' , len(set(all_singers)))
# Out:
# Total number of unique singers are 14872

# %% [markdown]
# ## Count of songs genre - wise

# %%
genre['genre'].value_counts()
# Out:
# Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# Children's Music    5403
# A Capella            119
# Name: genre, dtype: int64

# %% [markdown]
# ## Duration of Songs Genre-wise

# %%
plt.figure(figsize = (12,10))
plt.title('Duration of songs in Different genre')
sns.barplot(y = 'genre' , x = 'duration_ms' , data = genre)
plt.xlabel('duration in milli-seconds')
plt.ylabel('Genres')
# Out:
# Text(0, 0.5, 'Genres')

# %% [markdown]
# ## Top 3 Genres by popularity

# %%
plt.figure(figsize=(12,5))
famous = genre.sort_values("popularity" , ascending = False).head(5)
sns.barplot(y = 'genre' , x = 'popularity' , data= famous).set(title="Top 3 genres by popularity")
# Out:
# [Text(0.5, 1.0, 'Top 3 genres by popularity')]

# %% [markdown]
# ## Understanding variation of popularity with mode

# %%
plt.figure(figsize = (12,8))
sns.boxplot(x = 'popularity' , y = 'mode' , data = genre , orient = 'h' )
# Out:
# <AxesSubplot:xlabel='popularity', ylabel='mode'>

# %% [markdown]
# # Inference and Conclusion
# Dance genre is the most popular genre . Peaches is the most popular song with a popularity value of 100 whereas Newspaper reports on Abner is the least popular song with a popularity value of zero . The dataset doesn't have any duplicated values. In early 1920's music was not widely availiable and so people were not very aware of it . As years passed music became popular and so count of songs yearwise clearly depicts the trend . Relation beatween popularity versus loudness and popularity versus energy can be shown to have a positive slope indicating with increase in  loudness , energy popularity of song also increases . The varition of mode versus popularity has been clearly depicted with the help of the box plot indicating outliers as well and showing that mid 50 percentile lies between 30 and 55 . World genre has highest duration whereas children's music has the least duration . The popularity of song is not an indicative of the popularity of the artist . Thus one should look to promote music more related to dance ,  pop and rap which will bring in more customers . Various summarization techniques have been used and it is found that songs with popularity value 0 are the most and songs have key ranging from 0 - 11 . Moreover Comedy Genre has the most no of songs.

# %% [markdown]
# # Future  Ideas
# 1 I would like to see more of how duration impacts people's choices related to music <br>
# 2 What if culture affects metrics influencing popularity ?  For example, I would like to see whether region of people  more strongly contributes to popularity in India as compared to China.  I could also use more advanced statistical methods on the data  to check whether it can fit the data better<br>
# 3 Finally , one can deep dive into relations between increase of a popularity over the years for a particular genre<br>
